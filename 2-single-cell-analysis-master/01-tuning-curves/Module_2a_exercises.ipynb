# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 1 - simulating place cells
# ---
# Use the code we build to simulate place cells in the lesson.

# %%
import numpy as np
import scipy
import scipy.stats
import scipy.io
import matplotlib.pyplot as plt
from ipywidgets import interact
import ipywidgets as widgets
from tqdm import tqdm
import seaborn as sns
import pickle
import sys
import os
sys.path.append(os.path.abspath("code"))
from utils import download_data

sns.set_theme(context='notebook',style='white',font_scale=1.5,
              rc = {'axes.spines.top':False,'axes.spines.right':False})

# %%
# Download lesson data
download_data('https://surfdrive.surf.nl/files/index.php/s/z7mMiznEWOT0Iak')

# %%
track_length = 200. # the length of our linear track (eg in centimeter)
average_firing_rate = 5 # the peak firing rate, averaged across the population 
n_cells = 100 # how many cells we are recording
pf_centers = np.random.rand(n_cells) * track_length # the centers of the place fields for all cells drawn randomly with a uniform distribution on the track
pf_size = np.random.gamma(10, size=n_cells) # the size (width) of the place fields, drawn randomly from a gamma distribution 
pf_rate = np.random.exponential(scale=average_firing_rate, size=n_cells) # the peak firing rate for each cell, drawn from an exponential distribution

# %%
x = np.arange(0., 50., 0.1) # we use a grid with step 0.1
g = scipy.stats.gamma.pdf(x, 10)
plt.plot(x, g)
plt.xlabel('Place field size')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %%
bins = np.arange(0., 200.)
true_firing_rate_maps = np.zeros((n_cells, len(bins)))
for i in range(n_cells):
    true_firing_rate_maps[i,:] = pf_rate[i] * np.exp(-((bins-pf_centers[i])**2)/(2*pf_size[i]**2))

# %%
plt.figure(figsize=(10,5))
plt.imshow(true_firing_rate_maps, cmap='inferno')
plt.xlabel('location (cm)')
plt.ylabel('cell #')
# Out:
# Text(0, 0.5, 'cell #')

# %%
n_runs = 20 
av_running_speed = 10 # the average running speed (in cm/s)
fps = 30 # the number of "video frames" per second 
running_speed_a = np.random.chisquare(10, size=n_runs) # running speed in the two directions
running_speed_b = np.random.chisquare(10, size=n_runs) 

stopping_time_a = np.random.chisquare(15, size=n_runs) # the time the mouse will spend at the two ends of the track
stopping_time_b = np.random.chisquare(15, size=n_runs)

x = np.array([])
for i in range(n_runs):
    stop1 = np.ones((int(stopping_time_a[i]*fps),)) * 0.
    run_length = len(bins) * fps / running_speed_a[i]
    run1 = np.linspace(0., float(len(bins)-1), int(run_length))
    stop2 = np.ones((int(stopping_time_b[i]*fps),)) * (len(bins)-1.)
    run_length = len(bins) * fps / running_speed_b[i]
    run2 = np.linspace(len(bins)-1., 0., int(run_length))
    x = np.concatenate((x, stop1, run1, stop2, run2))
t = np.arange(len(x))/fps

# %%
plt.figure(figsize=(10,5))
plt.plot(t, x)
plt.xlabel('Time (s)')
plt.ylabel('position on track (cm)')
# Out:
# Text(0, 0.5, 'position on track (cm)')

# %%
sampling_rate = 10000.
t_sampling = np.arange(0, t[-1], 1. / sampling_rate)
x_sampling = np.floor(np.interp(t_sampling, t, x))
noise_firing_rate = 0.1 # the baseline noise firing rate
spikes = []

for i in tqdm(range(n_cells)):
    inst_rate = true_firing_rate_maps[i,x_sampling.astype(np.int32)] + noise_firing_rate
    spikes_loc = np.random.poisson(inst_rate/sampling_rate)
    sp = np.argwhere(spikes_loc)
    t_sp = t_sampling[sp]
    spikes.append(t_sp)
# Out:
# 100%|██████████| 100/100 [01:05<00:00,  1.52it/s]

# %%
spike_positions = [np.interp(s, t, x) for s in spikes]

# %% [markdown]
# ### Question A. Changing bin width

# %% [markdown]
# Explore what happens when you change the binning in the definition of the firing rate maps (`space_bins`). Make it coarser or broader.
#
#     Changing the binning in firing rate maps affects both the spatial resolution and the reliability of the estimated firing rates. As mentioned in the lecture, larger bins combine spikes over a wider area, which increases the statistical power and smooths out variability. As we see in the firing rate combined plot below, Larger bins combine spikes over a wider area, which increases the statistical power and smooths out variability, this results in broader and more robust place fields with higher average firing rates, but at the cost of reduced spacial specificity. On the other hand, smaller bins provide higher spatial resolution and can capture more detailed firing patterns, but the firing rates tend to be noisier and lower in magnitude because fewer spikes fall into each bin, reducing statistical reliability.

# %% [markdown]
# ### The original bin width (5 cm)

# %%
space_bins = np.arange(0., 200., 5.) 

# we compute histograms for eaxh cell
spikes_hist= [np.histogram(s, space_bins)[0] for s in spike_positions]

# put them together into a matrix of floating point numbers (for plotting)
spikes_hist = np.vstack(spikes_hist).astype(np.float64)

# we also need an "occupancy histogram" in order to normalize the firing rates maps 
occupancy = np.histogram(x, space_bins)[0] /  fps

firing_rate_maps = spikes_hist / occupancy

# %% [markdown]
# ### Larger bin width (10 cm)

# %%
space_bins = np.arange(0., 200., 10.)

# we compute histograms for eaxh cell
spikes_hist= [np.histogram(s, space_bins)[0] for s in spike_positions]

# put them together into a matrix of floating point numbers (for plotting)
spikes_hist = np.vstack(spikes_hist).astype(np.float64)

# we also need an "occupancy histogram" in order to normalize the firing rates maps 
occupancy = np.histogram(x, space_bins)[0] /  fps

firing_rate_maps_large = spikes_hist / occupancy

# %% [markdown]
# ### Smaller bin width (1 cm)

# %%
space_bins = np.arange(0., 200., 1.)

# we compute histograms for eaxh cell
spikes_hist= [np.histogram(s, space_bins)[0] for s in spike_positions]

# put them together into a matrix of floating point numbers (for plotting)
spikes_hist = np.vstack(spikes_hist).astype(np.float64)

# we also need an "occupancy histogram" in order to normalize the firing rates maps 
occupancy = np.histogram(x, space_bins)[0] /  fps

firing_rate_maps_small = spikes_hist / occupancy

# %% [markdown]
# ### All plotted together for comparison

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True) 

#plot 1: original bin width
peak_locations = firing_rate_maps.argmax(axis=1)
ix = np.argsort(peak_locations)
im0 = axes[0].imshow(firing_rate_maps[ix, :], cmap='inferno', extent=[0, 200, 0, n_cells])
axes[0].set_title('Original Binning')
axes[0].set_xlabel('Location (cm)')
axes[0].set_ylabel('Cell #')

#plot 2: large bin width
peak_locations = firing_rate_maps_large.argmax(axis=1)
ix = np.argsort(peak_locations)
im1 = axes[1].imshow(firing_rate_maps_large[ix, :], cmap='inferno', extent=[0, 200, 0, n_cells])
axes[1].set_title('Larger Binning')
axes[1].set_xlabel('Location (cm)')

#plot 3: small bin width
peak_locations = firing_rate_maps_small.argmax(axis=1)
ix = np.argsort(peak_locations)
im2 = axes[2].imshow(firing_rate_maps_small[ix, :], cmap='inferno', extent=[0, 200, 0, n_cells])
axes[2].set_title('Smaller Binning')
axes[2].set_xlabel('Location (cm)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Question B. The effect of baseline noise

# %% [markdown]
# In the spike train simulations, we add some "baseline" noise, not place-related to the firing. Which variable determines the noise level? Try to experiment with that variable and see what happens to the firing rate maps. What is the best approach to firing rate maps when the noise is high.
#
#         The variable that determines the noise level is `noise_firing_rate`. Noise  decreases the signal to noise ratio, so when increasing the noise, the place fields become less distinct and the firing rate maps we generate become more uniform across space. We can also see that below, in the original firing rate map the place field are a lot more narrow, making the specific location that the place cells are associated with in the environment a lot more specific (making them fire for more specific locations), compared to the firing rate map with higher noise. When there is a lot of noise, we could, just as what we did at question A, increase the bin size so that variability is reduced and random spikes (from noise) are averaged out.

# %%
sampling_rate = 10000.
t_sampling = np.arange(0, t[-1], 1. / sampling_rate)
x_sampling = np.floor(np.interp(t_sampling, t, x))
noise_firing_rate = 0.5 # increasing the noise
spikes = []

for i in tqdm(range(n_cells)):
    inst_rate = true_firing_rate_maps[i,x_sampling.astype(np.int32)] + noise_firing_rate
    spikes_loc = np.random.poisson(inst_rate/sampling_rate)
    sp = np.argwhere(spikes_loc)
    t_sp = t_sampling[sp]
    spikes.append(t_sp)

# %%
spike_positions = [np.interp(s, t, x) for s in spikes]

# %%
space_bins = np.arange(0., 200., 5.)

# we compute histograms for eaxh cell
spikes_hist= [np.histogram(s, space_bins)[0] for s in spike_positions]

# put them together into a matrix of floating point numbers (for plotting)
spikes_hist = np.vstack(spikes_hist).astype(np.float64)

# we also need an "occupancy histogram" in order to normalize the firing rates maps 
occupancy = np.histogram(x, space_bins)[0] /  fps

firing_rate_maps_noise = spikes_hist / occupancy

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5), sharey=True) 

#plot 1: original
peak_locations = firing_rate_maps.argmax(axis=1)
ix = np.argsort(peak_locations)
im0 = axes[0].imshow(firing_rate_maps[ix, :], cmap='inferno', extent=[0, 200, 0, n_cells])
axes[0].set_title('Original noise')
axes[0].set_xlabel('Location (cm)')
axes[0].set_ylabel('Cell #')

#plot 2: higher noise
peak_locations = firing_rate_maps_noise.argmax(axis=1)
ix = np.argsort(peak_locations)
im1 = axes[1].imshow(firing_rate_maps_noise[ix, :], cmap='inferno', extent=[0, 200, 0, n_cells])
axes[1].set_title('Higher noise')
axes[1].set_xlabel('Location (cm)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Question C. Using scipy.stats.gaussian_kde

# %% [markdown]
# We could use other approaches to firing rate maps: for example make the binning very small (down to 1 cm, which is the resolution of our "video" data, and then applying a gaussian smoother. Scipy has a Gaussian smoother at `scipy.stats.gaussian_kde`. Read the documentation for that function and apply it to the data to define the smoothed firing rate maps. Again, change the noise levels and see how the smoother changes.
#
#     KDE acts as both a smoother and a density estimator, allowing for continuous, bin-free estimation of spike and occupancy densities. The peaks are broader and less sharp but exhibit fewer discontinuities, making the spatial structure of firing fields clearer. While the original histogram method produces sharper features, it can introduce more noise artifacts.When adding noise, the KDE method is more robust: it preserves the general layout of place fields, whereas the histogram maps changed more noticeably.

# %% [markdown]
# ### Smoothed firing rate map

# %%
from scipy.stats import gaussian_kde

# %%
sampling_rate = 10000.
t_sampling = np.arange(0, t[-1], 1. / sampling_rate)
x_sampling = np.floor(np.interp(t_sampling, t, x))
noise_firing_rate = 0.1 # increasing the noise
spikes = []

for i in tqdm(range(n_cells)):
    positions = np.array(spike_positions[i]).reshape(1, -1)  
    
    kde = gaussian_kde(positions)
    spike_density = kde(space_centers.reshape(1, -1))  
    
    kde_occ = gaussian_kde(x.reshape(1, -1))  
    occupancy_density = kde_occ(space_centers.reshape(1, -1))
    
    firing_rate = spike_density / (occupancy_density + epsilon)
    smoothed_firing_rate_maps.append(firing_rate)

smoothed_array = np.array(smoothed_firing_rate_maps)
# Out:
# 100%|██████████| 100/100 [00:50<00:00,  1.99it/s]

# %% [markdown]
# ### Compare original to smoothed firing rate map

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5), sharey=True) 

#plot 1: original
peak_locations = firing_rate_maps.argmax(axis=1)
ix = np.argsort(peak_locations)
im0 = axes[0].imshow(firing_rate_maps[ix, :], cmap='inferno', extent=[0, 200, 0, n_cells])
axes[0].set_title('Original histogram')
axes[0].set_xlabel('Location (cm)')
axes[0].set_ylabel('Cell #')

#plot 2: smoothed
peak_locations = smoothed_array.argmax(axis=1)
ix = np.argsort(peak_locations)
im1 = axes[1].imshow(smoothed_array[ix, :], cmap='inferno', extent=[0, 200, 0, n_cells])
axes[1].set_title('Gaussian smoother')
axes[1].set_xlabel('Location (cm)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Question D. Place field center and place field width

# %% [markdown]
# When analyzing place fields, two important quantities are the place field center and the place field width. The place field center may be defined in many ways, but one is to compute the "center of mass" of the spikes according to the equation
#
# $$ c_{pf} = \frac{1}{N_{spikes}} \sum_{i} L_i $$
#
# where the sum on $i$ runs on all spikes emitted by a cell and $L_i$ is the location at which the i-th spike was emitted. Calculate this for each cell. Compare with the "true" place field centers from the simulations (which variables are we talking about?)

# %%
# Compute center of mass (mean spike location) for each cell
place_field_centers = np.array([
    np.mean(spikes)
    for spikes in spike_positions
])

# %% [markdown]
# The "true" place field center variable from the simulated data is called pf_centers. We compare that to the center of mass that we calculated for each cell.

# %%
#make plot to compare
plt.figure(figsize=(5,5))
plt.scatter(pf_centers, place_field_centers, alpha=0.7)
plt.plot([0, 200], [0, 200], '--', color='gray')  
plt.xlabel("True place field center (cm)")
plt.ylabel("Estimated center of mass (cm)")
plt.grid(True)
